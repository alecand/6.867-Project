# %%
from sklearn.datasets import fetch_olivetti_faces
from skimage.measure import block_reduce
import matplotlib.pyplot as plt
import numpy as np

f = fetch_olivetti_faces(shuffle = False)
face_images = f.images
face_rows = f.data
# Out:
#   File "<ipython-input-19-2f658f11c888>", line 3
#     from skimage import color,io,measure.block_reduce
#                                         ^
# SyntaxError: invalid syntax

# %%
for i in range(10):
    plt.imshow(face_images[i], cmap = plt.cm.gray)
    plt.show()

# %%
people_list = np.loadtxt('people.txt').astype(int)
ok_dirs = []

for i in range(1,1001):
    if not i in people_list:
#         ok_dirs.append(r'Flickr Images\im' + str(i) + '.jpg') # Windows
        ok_dirs.append(r'Flickr Images/im' + str(i) + '.jpg') # Mac

# %%
from skimage import color, io

img_list = [color.rgb2gray(io.imread(ok_dirs[i])) for i in range(len(ok_dirs))][:500]
shape_list = [io.imread(ok_dirs[i]).shape for i in range(len(ok_dirs))]

# plt.imshow(img_list[10],cmap = plt.cm.gray)
# plt.show()
# len(img_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-177a139a4f0f> in <module>()
#       1 from skimage import color, io
#       2
# ----> 3 img_list = [color.rgb2gray(io.imread(ok_dirs[i])) for i in range(len(ok_dirs))][:500]
#       4 shape_list = [io.imread(ok_dirs[i]).shape for i in range(len(ok_dirs))]
#       5
#
# /Users/aandersonlaptop/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/skimage/io/_io.pyc in imread(fname, as_grey, plugin, flatten, **plugin_args)
#      59
#      60     with file_or_url_context(fname) as fname:
# ---> 61         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      62
#      63     if not hasattr(img, 'ndim'):
#
# /Users/aandersonlaptop/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/skimage/io/manage_plugins.pyc in call_plugin(kind, *args, **kwargs)
#     209                                (plugin, kind))
#     210
# --> 211     return func(*args, **kwargs)
#     212
#     213
#
# /Users/aandersonlaptop/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/skimage/io/_plugins/pil_plugin.pyc in imread(fname, dtype, img_num, **kwargs)
#      34     if isinstance(fname, string_types):
#      35         with open(fname, 'rb') as f:
# ---> 36             im = Image.open(f)
#      37             return pil_to_ndarray(im, dtype=dtype, img_num=img_num)
#      38     else:
#
# /Users/aandersonlaptop/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/PIL/Image.pyc in open(fp, mode)
#    1956         """Returns a QPixmap copy of this image"""
#    1957         from PIL import ImageQt
# -> 1958         if not ImageQt.qt_is_installed:
#    1959             raise ImportError("Qt bindings are not installed")
#    1960         return ImageQt.toqpixmap(self)
#
# /Users/aandersonlaptop/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/PIL/Image.pyc in preinit()
#     300     :param mode: Input mode.
#     301     :returns: "L" or "RGB".
# --> 302     :exception KeyError: If the input mode was not a standard mode.
#     303     """
#     304     return ImageMode.getmode(mode).basemode
#
# /Users/aandersonlaptop/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/PIL/GifImagePlugin.py in <module>()
#     767 Image.register_open(GifImageFile.format, GifImageFile, _accept)
#     768 Image.register_save(GifImageFile.format, _save)
# --> 769 Image.register_save_all(GifImageFile.format, _save_all)
#     770 Image.register_extension(GifImageFile.format, ".gif")
#     771 Image.register_mime(GifImageFile.format, "image/gif")
#
# AttributeError: 'module' object has no attribute 'register_save_all'

# %%
np.random.seed(0)

dim_param = 64

gen_image_list = []

rand_subs = []

for shape in shape_list:
    xs = np.random.randint(0, shape[0]-dim_param, size = 5)
    ys = np.random.randint(0, shape[1]-dim_param, size = 5)
    rand_subs.append(zip(xs, ys))

for i in range(len(img_list)):
    for dim in rand_subs[i][:4]:
        gen_image_list.append(img_list[i][dim[0]:dim[0]+dim_param, dim[1]:dim[1]+dim_param])
        
    
for i in range(10):
    plt.imshow(gen_image_list[i], cmap = plt.cm.gray)
    plt.show()

# %%
X_train = list(face_images)[:300] * 5
X_train.extend(gen_image_list[:1500])
Y_train = [1 for _ in range(1500)]
Y_train.extend([0 for _ in range(1500)])
X_train_lr = np.array(X_train)
X_train_lr = X_train_lr.reshape(-1, X_train_lr.shape[0]).T



X_test = list(face_images)[300:] * 5
X_test.extend(gen_image_list[1500:])
Y_test = [1 for _ in range(500)]
Y_test.extend([0 for _ in range(500)])
X_test_lr = np.array(X_test)
X_test_lr = X_test_lr.reshape(-1, X_test_lr.shape[0]).T

# %%
from sklearn.linear_model import LogisticRegression

lr_baseline_model = LogisticRegression(C =10)
lr_baseline_model.fit(X_train_lr, Y_train)
# Out:
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
coef_mat = lr_baseline_model.coef_.reshape(64,64)
norm_coef_mat = (coef_mat - np.min(coef_mat))/(np.max(coef_mat) - np.min(coef_mat))

# %%
plt.imshow(norm_coef_mat, cmap = plt.cm.gray)
plt.show()

# %%
lr_baseline_model.score(X_test_lr[:100], Y_test[:100])
# Out:
# 1.0

# %%
plt.imshow(sum(i for i in f.images)/len(f.images), cmap = plt.cm.gray)
plt.show()
