# %%
from sklearn.datasets import fetch_olivetti_faces
from skimage.measure import block_reduce
import matplotlib.pyplot as plt
import numpy as np

f = fetch_olivetti_faces(shuffle = True)
face_images = [block_reduce(i, block_size = (2,2), func = np.mean) for i in f.images]
face_rows = f.data

# %%
for i in range(10):
    plt.imshow(face_images[i], cmap = plt.cm.gray)
    plt.show()

# %%
people_list = np.loadtxt('people.txt').astype(int)
ok_dirs = []

for i in range(1,1001):
    if not i in people_list:
        ok_dirs.append(r'Flickr Images\im' + str(i) + '.jpg')

# %%
from skimage import color, io

img_list = [color.rgb2gray(io.imread(ok_dirs[i])) for i in range(len(ok_dirs))][:500]
shape_list = [io.imread(ok_dirs[i]).shape for i in range(len(ok_dirs))]

# plt.imshow(img_list[10],cmap = plt.cm.gray)
# plt.show()
# len(img_list)
# Out:
# 500

# %%
np.random.seed(0)

gen_image_list = []

rand_subs = []

for shape in shape_list:
    xs = np.random.randint(0, shape[0]-64, size = 5)
    ys = np.random.randint(0, shape[1]-64, size = 5)
    rand_subs.append(zip(xs, ys))

for i in range(len(img_list)):
    for dim in rand_subs[i]:
        gen_image_list.append(img_list[i][dim[0]:dim[0]+64, dim[1]:dim[1]+64])
        
    
# for i in range(10):
#     plt.imshow(gen_image_list[i], cmap = plt.cm.gray)
#     plt.show()

# %%
shape_list
# Out:
# [(316L, 500L, 3L),
#  (375L, 500L, 3L),
#  (500L, 341L, 3L),
#  (333L, 500L, 3L),
#  (500L, 384L, 3L),
#  (333L, 500L, 3L),
#  (500L, 500L, 3L),
#  (333L, 500L, 3L),
#  (336L, 500L, 3L),
#  (333L, 500L, 3L),
#  (354L, 500L, 3L),
#  (500L, 375L, 3L),
#  (376L, 500L, 3L),
#  (333L, 500L, 3L),
#  (375L, 500L, 3L),
#  (333L, 500L, 3L),
#  (418L, 500L, 3L),
#  (332L, 500L, 3L),
#  (332L, 500L, 3L),
#  (354L, 500L, 3L),
#  (333L, 500L, 3L),
#  (500L, 334L, 3L),
#  (395L, 500L, 3L),
#  (331L, 500L, 3L),
#  (335L, 500L, 3L),
#  (500L, 375L, 3L),
#  (375L, 500L, 3L),
#  (334L, 500L, 3L),
#  (500L, 500L, 3L),
#  (333L, 500L, 3L),
#  (334L, 500L, 3L),
#  (338L, 500L, 3L),
#  (500L, 337L, 3L),
#  (500L, 398L, 3L),
#  (375L, 500L, 3L),
#  (334L, 500L, 3L),
#  (375L, 500L, 3L),
#  (334L, 500L, 3L),
#  (375L, 500L, 3L),
#  (333L, 500L, 3L),
#  (500L, 500L, 3L),
#  (333L, 500L, 3L),
#  (359L, 500L, 3L),
#  (500L, 500L, 3L),
#  (500L, 500L, 3L),
#  (377L, 500L, 3L),
#  (333L, 500L, 3L),
#  (375L, 500L, 3L),
#  (500L, 333L, 3L),
#  (334L, 500L, 3L),
#  (378L, 500L, 3L),
#  (332L, 500L, 3L),
#  (500L, 375L, 3L),
#  (263L, 500L, 3L),
#  (332L, 500L, 3L),
#  (500L, 375L, 3L),
#  (333L, 500L, 3L),
#  (376L, 500L, 3L),
#  (325L, 500L, 3L),
#  (333L, 500L, 3L),
#  (335L, 500L, 3L),
#  (500L, 334L, 3L),
#  (315L, 500L, 3L),
#  (335L, 500L, 3L),
#  (333L, 500L, 3L),
#  (330L, 500L, 3L),
#  (500L, 333L, 3L),
#  (333L, 500L, 3L),
#  (500L, 500L, 3L),
#  (341L, 500L, 3L),
#  (335L, 500L, 3L),
#  (397L, 500L, 3L),
#  (375L, 500L, 3L),
#  (375L, 500L, 3L),
#  (375L, 500L, 3L),
#  (338L, 500L, 3L),
#  (375L, 500L, 3L),
#  (334L, 500L, 3L),
#  (375L, 500L, 3L),
#  (334L, 500L, 3L),
#  (500L, 358L, 3L),
#  (500L, 333L, 3L),
#  (281L, 500L, 3L),
#  (500L, 333L, 3L),
#  (375L, 500L, 3L),
#  (333L, 500L, 3L),
#  (500L, 500L, 3L),
#  (333L, 500L, 3L),
#  (500L, 375L, 3L),
#  (333L, 500L, 3L),
#  (500L, 393L, 3L),
#  (375L, 500L, 3L),
#  (375L, 500L, 3L),
#  (335L, 500L, 3L),
#  (335L, 500L, 3L),
#  (359L, 500L, 3L),
#  (375L, 500L, 3L),
#  (500L, 409L, 3L),
#  (500L, 434L, 3L),
#  (360L, 500L, 3L),
#  (500L, 335L, 3L),
#  (328L, 500L, 3L),
#  (343L, 500L, 3L),
#  (357L, 500L, 3L),
#  (333L, 500L, 3L),
#  (375L, 500L, 3L),
#  (375L, 500L, 3L),
#  (350L, 500L, 3L),
#  (375L, 500L, 3L),
#  (333L, 500L, 3L),
#  (500L, 333L, 3L),
#  (271L, 500L, 3L),
#  (384L, 500L, 3L),
#  (500L, 333L, 3L),
#  (333L, 500L, 3L),
#  (500L, 500L, 3L),
#  (333L, 500L, 3L),
#  (333L, 500L, 3L),
#  (334L, 500L, 3L),
#  (375L, 500L, 3L),
#  (335L, 500L, 3L),
#  (365L, 500L, 3L),
#  (375L, 500L, 3L),
#  (500L, 334L, 3L),
#  (371L, 500L, 3L),
#  (386L, 500L, 3L),
#  (312L, 500L, 3L),
#  (337L, 500L, 3L),
#  (500L, 500L, 3L),
#  (375L, 500L, 3L),
#  (333L, 500L, 3L),
#  (375L, 500L, 3L),
#  (411L, 500L, 3L),
#  (500L, 500L, 3L),
#  (181L, 500L, 3L),
#  (500L, 500L, 3L),
#  (375L, 500L, 3L),
#  (395L, 500L, 3L),
#  (375L, 500L, 3L),
#  (500L, 266L, 3L),
#  (333L, 500L, 3L),
#  (333L, 500L, 3L),
#  (357L, 500L, 3L),
#  (333L, 500L, 3L),
#  (500L, 337L, 3L),
#  (467L, 500L, 3L),
#  (375L, 500L, 3L),
#  (375L, 500L, 3L),
#  (333L, 500L, 3L),
#  (368L, 500L, 3L),
#  (375L, 500L, 3L),
#  (500L, 437L, 3L),
#  (500L, 375L, 3L),
#  (351L, 500L, 3L),
#  (500L, 294L, 3L),
#  (339L, 500L, 3L),
#  (333L, 500L, 3L),
#  (340L, 500L, 3L),
#  (333L, 500L, 3L),
#  (450L, 500L, 3L),
#  (500L, 439L, 3L),
#  (500L, 500L, 3L),
#  (333L, 500L, 3L),
#  (375L, 500L, 3L),
#  (334L, 500L, 3L),
#  (375L, 500L, 3L),
#  (194L, 500L, 3L),
#  (375L, 500L, 3L),
#  (375L, 500L, 3L),
#  (500L, 446L, 3L),
#  (300L, 500L, 3L),
#  (382L, 500L, 3L),
#  (386L, 500L, 3L),
#  (375L, 500L, 3L),
#  (448L, 500L, 3L),
#  (500L, 375L, 3L),
#  (375L, 500L, 3L),
#  (500L, 492L, 3L),
#  (400L, 500L, 3L),
#  (318L, 500L, 3L),
#  (334L, 500L, 3L),
#  (298L, 500L, 3L),
#  (500L, 500L, 3L),
#  (377L, 500L, 3L),
#  (415L, 500L, 3L),
#  (500L, 326L, 3L),
#  (333L, 500L, 3L),
#  (375L, 500L, 3L),
#  (375L, 500L, 3L),
#  (500L, 332L, 3L),
#  (333L, 500L, 3L),
#  (375L, 500L, 3L),
#  (500L, 346L, 3L),
#  (334L, 500L, 3L),
#  (357L, 500L, 3L),
#  (500L, 332L, 3L),
#  (246L, 500L, 3L),
#  (500L, 333L, 3L),
#  (275L, 500L, 3L),
#  (333L, 500L, 3L),
#  (336L, 500L, 3L),
#  (375L, 500L, 3L),
#  (333L, 500L, 3L),
#  (375L, 500L, 3L),
#  (281L, 500L, 3L),
#  (332L, 500L, 3L),
#  (375L, 500L, 3L),
#  (374L, 500L, 3L),
#  (289L, 500L, 3L),
#  (500L, 375L, 3L),
#  (375L, 500L, 3L),
#  (500L, 375L, 3L),
#  (333L, 500L, 3L),
#  (500L, 467L, 3L),
#  (333L, 500L, 3L),
#  (334L, 500L, 3L),
#  (480L, 360L, 3L),
#  (375L, 500L, 3L),
#  (500L, 434L, 3L),
#  (334L, 500L, 3L),
#  (345L, 500L, 3L),
#  (300L, 400L, 3L),
#  (281L, 500L, 3L),
#  (381L, 500L, 3L),
#  (375L, 500L, 3L),
#  (333L, 500L, 3L),
#  (365L, 500L, 3L),
#  (471L, 500L, 3L),
#  (379L, 500L, 3L),
#  (500L, 480L, 3L),
#  (333L, 500L, 3L),
#  (500L, 338L, 3L),
#  (333L, 500L, 3L),
#  (333L, 500L, 3L),
#  (334L, 500L, 3L),
#  (468L, 500L, 3L),
#  (360L, 500L, 3L),
#  (333L, 500L, 3L),
#  (333L, 500L, 3L),
#  (375L, 500L, 3L),
#  (333L, 500L, 3L),
#  (337L, 500L, 3L),
#  (333L, 500L, 3L),
#  (343L, 500L, 3L),
#  (400L, 500L, 3L),
#  (375L, 500L, 3L),
#  (332L, 500L, 3L),
#  (280L, 500L, 3L),
#  (470L, 500L, 3L),
#  (375L, 500L, 3L),
#  (333L, 500L, 3L),
#  (500L, 349L, 3L),
#  (375L, 500L, 3L),
#  (334L, 500L, 3L),
#  (333L, 500L, 3L),
#  (333L, 500L, 3L),
#  (335L, 500L, 3L),
#  (375L, 500L, 3L),
#  (500L, 375L, 3L),
#  (376L, 500L, 3L),
#  (500L, 333L, 3L),
#  (500L, 500L, 3L),
#  (500L, 409L, 3L),
#  (500L, 323L, 3L),
#  (334L, 500L, 3L),
#  (333L, 500L, 3L),
#  (500L, 500L, 3L),
#  (332L, 500L, 3L),
#  (313L, 500L, 3L),
#  (334L, 500L, 3L),
#  (370L, 500L, 3L),
#  (333L, 500L, 3L),
#  (375L, 500L, 3L),
#  (306L, 500L, 3L),
#  (291L, 500L, 3L),
#  (375L, 500L, 3L),
#  (500L, 375L, 3L),
#  (337L, 500L, 3L),
#  (333L, 500L, 3L),
#  (443L, 500L, 3L),
#  (375L, 500L, 3L),
#  (500L, 328L, 3L),
#  (375L, 500L, 3L),
#  (335L, 500L, 3L),
#  (333L, 500L, 3L),
#  (282L, 500L, 3L),
#  (375L, 500L, 3L),
#  (318L, 500L, 3L),
#  (335L, 500L, 3L),
#  (375L, 500L, 3L),
#  (375L, 500L, 3L),
#  (500L, 333L, 3L),
#  (333L, 500L, 3L),
#  (358L, 500L, 3L),
#  (500L, 333L, 3L),
#  (500L, 333L, 3L),
#  (333L, 500L, 3L),
#  (333L, 500L, 3L),
#  (500L, 333L, 3L),
#  (332L, 500L, 3L),
#  (357L, 500L, 3L),
#  (500L, 333L, 3L),
#  (500L, 334L, 3L),
#  (500L, 500L, 3L),
#  (332L, 500L, 3L),
#  (364L, 500L, 3L),
#  (375L, 500L, 3L),
#  (300L, 500L, 3L),
#  (375L, 500L, 3L),
#  (338L, 500L, 3L),
#  (332L, 500L, 3L),
#  (400L, 500L, 3L),
#  (500L, 490L, 3L),
#  (375L, 500L, 3L),
#  (500L, 324L, 3L),
#  (375L, 500L, 3L)]
